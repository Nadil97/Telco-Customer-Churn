# %% [markdown]
# # Import Library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
Telco_customer=pd.read_csv('D:\Git hub projects\Telco Customer Churn\WA_Fn-UseC_-Telco-Customer-Churn.csv')

# %%
Telco_customer.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
Telco_customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
Telco_customer.isnull()
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0          False   False          False    False       False   False
# 1          False   False          False    False       False   False
# 2          False   False          False    False       False   False
# 3          False   False          False    False       False   False
# 4          False   False          False    False       False   False
# ...          ...     ...            ...      ...         ...     ...
# 7038       False   False          False    False       False   False
# 7039       False   False          False    False       False   False
# 7040       False   False          False    False       False   False
# 7041       False   False          False    False       False   False
# 7042       False   False          False    False       False   False
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# ...

# %% [markdown]
# # Checking Null data

# %%
sns.heatmap(Telco_customer.isnull(),yticklabels=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Cheking data set

# %%
sns.countplot(x='Churn',data=Telco_customer)
# Out:
# <AxesSubplot:xlabel='Churn', ylabel='count'>

# %%
sns.countplot(x='Churn',hue="gender",data=Telco_customer)
# Out:
# <AxesSubplot:xlabel='Churn', ylabel='count'>

# %%
sns.countplot(x='Churn',hue='Contract',data=Telco_customer)
# Out:
# <AxesSubplot:xlabel='Churn', ylabel='count'>

# %%
Telco_customer
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %% [markdown]
# # Data preprocesing

# %%
yes_no_mapping= {'Yes':1,'No':0}
Telco_customer['Partner']=Telco_customer['Partner'].map(yes_no_mapping)
Telco_customer['Dependents']=Telco_customer['Dependents'].map(yes_no_mapping)
Telco_customer['PhoneService']=Telco_customer['PhoneService'].map(yes_no_mapping)

# %%
Telco_customer
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0     7590-VHVEG  Female              0        1           0       1
# 1     5575-GNVDE    Male              0        0           0      34
# 2     3668-QPYBK    Male              0        0           0       2
# 3     7795-CFOCW    Male              0        0           0      45
# 4     9237-HQITU  Female              0        0           0       2
# ...          ...     ...            ...      ...         ...     ...
# 7038  6840-RESVB    Male              0        1           1      24
# 7039  2234-XADUH  Female              0        1           1      72
# 7040  4801-JZAZL  Female              0        1           1      11
# 7041  8361-LTMKD    Male              1        1           0       4
# 7042  3186-AJIEK    Male              0        0           0      66
#
#       PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# ...

# %%
internetServiceMaping = {'Yes':1,'No':0,'No internet service':0}
Telco_customer['OnlineSecurity']=Telco_customer['OnlineSecurity'].map(internetServiceMaping)
Telco_customer['OnlineBackup']=Telco_customer['OnlineBackup'].map(internetServiceMaping)
Telco_customer['DeviceProtection']=Telco_customer['DeviceProtection'].map(internetServiceMaping)
Telco_customer['TechSupport']=Telco_customer['TechSupport'].map(internetServiceMaping)
Telco_customer['StreamingTV']=Telco_customer['StreamingTV'].map(internetServiceMaping)
Telco_customer['StreamingMovies']=Telco_customer['StreamingMovies'].map(internetServiceMaping)
phoneServiceMappping={'Yes':1,'No':0,'No phone service':0}
Telco_customer['MultipleLines']=Telco_customer['MultipleLines'].map(phoneServiceMappping)

# %%
Telco_customer
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0     7590-VHVEG  Female              0        1           0       1
# 1     5575-GNVDE    Male              0        0           0      34
# 2     3668-QPYBK    Male              0        0           0       2
# 3     7795-CFOCW    Male              0        0           0      45
# 4     9237-HQITU  Female              0        0           0       2
# ...          ...     ...            ...      ...         ...     ...
# 7038  6840-RESVB    Male              0        1           1      24
# 7039  2234-XADUH  Female              0        1           1      72
# 7040  4801-JZAZL  Female              0        1           1      11
# 7041  8361-LTMKD    Male              1        1           0       4
# 7042  3186-AJIEK    Male              0        0           0      66
#
#       PhoneService  MultipleLines InternetService  OnlineSecurity  ...  \
# ...

# %%
dsl_Fiber_Mapping= {'DSL':1,'Fiber optic':1,'No':0}
Telco_customer['InternetService']=Telco_customer['InternetService'].map(dsl_Fiber_Mapping)

# %%
Telco_customer
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0     7590-VHVEG  Female              0        1           0       1
# 1     5575-GNVDE    Male              0        0           0      34
# 2     3668-QPYBK    Male              0        0           0       2
# 3     7795-CFOCW    Male              0        0           0      45
# 4     9237-HQITU  Female              0        0           0       2
# ...          ...     ...            ...      ...         ...     ...
# 7038  6840-RESVB    Male              0        1           1      24
# 7039  2234-XADUH  Female              0        1           1      72
# 7040  4801-JZAZL  Female              0        1           1      11
# 7041  8361-LTMKD    Male              1        1           0       4
# 7042  3186-AJIEK    Male              0        0           0      66
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# ...

# %%
contrct_mapping={'Month-to-month':'MM','One year':'OY','Two year':'TY'}
Telco_customer['Contract']=Telco_customer['Contract'].map(contrct_mapping)

# %%
Telco_customer
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0     7590-VHVEG  Female              0        1           0       1
# 1     5575-GNVDE    Male              0        0           0      34
# 2     3668-QPYBK    Male              0        0           0       2
# 3     7795-CFOCW    Male              0        0           0      45
# 4     9237-HQITU  Female              0        0           0       2
# ...          ...     ...            ...      ...         ...     ...
# 7038  6840-RESVB    Male              0        1           1      24
# 7039  2234-XADUH  Female              0        1           1      72
# 7040  4801-JZAZL  Female              0        1           1      11
# 7041  8361-LTMKD    Male              1        1           0       4
# 7042  3186-AJIEK    Male              0        0           0      66
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# ...

# %%
Telco_customer['PaperlessBilling']=Telco_customer['PaperlessBilling'].map(yes_no_mapping)

# %%
Telco_customer
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0     7590-VHVEG  Female              0        1           0       1
# 1     5575-GNVDE    Male              0        0           0      34
# 2     3668-QPYBK    Male              0        0           0       2
# 3     7795-CFOCW    Male              0        0           0      45
# 4     9237-HQITU  Female              0        0           0       2
# ...          ...     ...            ...      ...         ...     ...
# 7038  6840-RESVB    Male              0        1           1      24
# 7039  2234-XADUH  Female              0        1           1      72
# 7040  4801-JZAZL  Female              0        1           1      11
# 7041  8361-LTMKD    Male              1        1           0       4
# 7042  3186-AJIEK    Male              0        0           0      66
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# ...

# %%
payment_mapping = {'Bank transfer (automatic)':'Bank','Credit card (automatic)':'Card','Electronic check':'Cheak','Mailed check':'Cheak'}
Telco_customer['PaymentMethod']=Telco_customer['PaymentMethod'].map(payment_mapping)

# %%
Telco_customer
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0     7590-VHVEG  Female              0        1           0       1
# 1     5575-GNVDE    Male              0        0           0      34
# 2     3668-QPYBK    Male              0        0           0       2
# 3     7795-CFOCW    Male              0        0           0      45
# 4     9237-HQITU  Female              0        0           0       2
# ...          ...     ...            ...      ...         ...     ...
# 7038  6840-RESVB    Male              0        1           1      24
# 7039  2234-XADUH  Female              0        1           1      72
# 7040  4801-JZAZL  Female              0        1           1      11
# 7041  8361-LTMKD    Male              1        1           0       4
# 7042  3186-AJIEK    Male              0        0           0      66
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# ...

# %%
Telco_customer['Churn']=Telco_customer['Churn'].map(yes_no_mapping)

# %%
Telco_customer
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0     7590-VHVEG  Female              0        1           0       1
# 1     5575-GNVDE    Male              0        0           0      34
# 2     3668-QPYBK    Male              0        0           0       2
# 3     7795-CFOCW    Male              0        0           0      45
# 4     9237-HQITU  Female              0        0           0       2
# ...          ...     ...            ...      ...         ...     ...
# 7038  6840-RESVB    Male              0        1           1      24
# 7039  2234-XADUH  Female              0        1           1      72
# 7040  4801-JZAZL  Female              0        1           1      11
# 7041  8361-LTMKD    Male              1        1           0       4
# 7042  3186-AJIEK    Male              0        0           0      66
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# ...

# %%
pd.get_dummies(Telco_customer['gender'],drop_first=True)
# Out:
#       Male
# 0        0
# 1        1
# 2        1
# 3        1
# 4        0
# ...    ...
# 7038     1
# 7039     0
# 7040     0
# 7041     1
# 7042     1
#
# [7043 rows x 1 columns]

# %%
sex =pd.get_dummies(Telco_customer['gender'],drop_first=True)

# %%
contract =pd.get_dummies(Telco_customer['Contract'],drop_first=True)

# %%
contract
# Out:
#       OY  TY
# 0      0   0
# 1      1   0
# 2      0   0
# 3      1   0
# 4      0   0
# ...   ..  ..
# 7038   1   0
# 7039   1   0
# 7040   0   0
# 7041   0   0
# 7042   0   1
#
# [7043 rows x 2 columns]

# %%
paymethod =contract =pd.get_dummies(Telco_customer['PaymentMethod'],drop_first=True)

# %%
paymethod.head()
# Out:
#    Card  Cheak
# 0     0      1
# 1     0      1
# 2     0      1
# 3     0      0
# 4     0      1

# %%
contract.head()
# Out:
#    Card  Cheak
# 0     0      1
# 1     0      1
# 2     0      1
# 3     0      0
# 4     0      1

# %%
sex.head()
# Out:
#    Male
# 0     0
# 1     1
# 2     1
# 3     1
# 4     0

# %% [markdown]
# # Concatinate dummy variable

# %%
Telco_customer= pd.concat([Telco_customer,sex,contract,paymethod],axis=1)

# %%
Telco_customer
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0     7590-VHVEG  Female              0        1           0       1
# 1     5575-GNVDE    Male              0        0           0      34
# 2     3668-QPYBK    Male              0        0           0       2
# 3     7795-CFOCW    Male              0        0           0      45
# 4     9237-HQITU  Female              0        0           0       2
# ...          ...     ...            ...      ...         ...     ...
# 7038  6840-RESVB    Male              0        1           1      24
# 7039  2234-XADUH  Female              0        1           1      72
# 7040  4801-JZAZL  Female              0        1           1      11
# 7041  8361-LTMKD    Male              1        1           0       4
# 7042  3186-AJIEK    Male              0        0           0      66
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# ...

# %%
Telco_customer.drop(['customerID','gender','PaymentMethod','Contract'],axis=1,inplace=True)

# %%
Telco_customer
# Out:
#       SeniorCitizen  Partner  Dependents  tenure  PhoneService  MultipleLines  \
# 0                 0        1           0       1             0              0
# 1                 0        0           0      34             1              0
# 2                 0        0           0       2             1              0
# 3                 0        0           0      45             0              0
# 4                 0        0           0       2             1              0
# ...             ...      ...         ...     ...           ...            ...
# 7038              0        1           1      24             1              1
# 7039              0        1           1      72             1              1
# 7040              0        1           1      11             0              0
# 7041              1        1           0       4             1              1
# 7042              0        0           0      66             1              0
#
# ...
